# %% [markdown]
# # DECISION TREE PROJECT

# %%
#Uber Stocks Dataset 2025

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

# %% [markdown]
# # load the data

# %%
file_path = r"C:\Users\Admin\Downloads\uber_stock_data.csv"
df = pd.read_csv(r"C:\Users\Admin\Downloads\uber_stock_data.csv")

# %%
df
# Out:
#             Date  Adj Close      Close       High        Low       Open  \
# 0     2019-05-10  41.570000  41.570000  45.000000  41.060001  42.000000
# 1     2019-05-13  37.099998  37.099998  39.240002  36.080002  38.790001
# 2     2019-05-14  39.959999  39.959999  39.959999  36.849998  38.310001
# 3     2019-05-15  41.290001  41.290001  41.880001  38.950001  39.369999
# 4     2019-05-16  43.000000  43.000000  44.060001  41.250000  41.480000
# ...          ...        ...        ...        ...        ...        ...
# 1439  2025-01-30  66.589996  66.589996  67.222000  63.419998  63.419998
# 1440  2025-01-31  66.849998  66.849998  67.870003  66.333000  67.089996
# 1441  2025-02-03  67.290001  67.290001  68.849998  65.178001  65.300003
# 1442  2025-02-04  69.750000  69.750000  70.190002  67.690002  67.690002
# 1443  2025-02-05  64.480003  64.480003  66.750000  63.500000  66.500000
#
#          Volume
# 0     186322500
# 1      79442400
# 2      46661100
# 3      36086100
# ...

# %%
df.head()
df.tail()
df.info()
df.columns
df.isnull()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1416 entries, 28 to 1443
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1416 non-null   datetime64[ns]
#  1   Adj Close     1416 non-null   float64
#  2   Close         1416 non-null   float64
#  3   High          1416 non-null   float64
#  4   Low           1416 non-null   float64
#  5   Open          1416 non-null   float64
#  6   Volume        1416 non-null   int64
#  7   Date_ordinal  1416 non-null   int64
#  8   MA_5          1416 non-null   float64
#  9   MA_10         1416 non-null   float64
#  10  Volatility    1416 non-null   float64
#  11  Prev_Close    1416 non-null   float64
# dtypes: datetime64[ns](1), float64(9), int64(2)
# memory usage: 143.8 KB
# Date            0
# Adj Close       0
# Close           0
# High            0
# Low             0
# Open            0
# Volume          0
# Date_ordinal    0
# MA_5            0
# ...

# %%
# Initialize and train the Decision Tree model
model = DecisionTreeRegressor(max_depth=5, random_state=42)
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# %%
# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error: {mae:.4f}")
# Out:
# Mean Absolute Error: 0.4780

# %%
plt.figure(figsize=(12,6))

# Plot actual vs predicted stock prices
plt.scatter(X_test['Date_ordinal'], y_test, label="Actual Price", color='blue')
plt.scatter(X_test['Date_ordinal'], y_pred, label="Predicted Price", color='red')

plt.xlabel("Date")
plt.ylabel("Stock Closing Price")
plt.title("Uber Stock Price Prediction - Decision Tree")
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df['Date'], df['Close'], label="Closing Price", color='blue')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Uber Stock Price Trend')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
df.columns
# Out:
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'Price_Change',
#        'Target', 'MA_5', 'MA_10', 'Volatility', 'Prev_Close'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1433 entries, 2019-05-28 to 2025-02-05
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Adj Close     1433 non-null   float64
#  1   Close         1433 non-null   float64
#  2   High          1433 non-null   float64
#  3   Low           1433 non-null   float64
#  4   Open          1433 non-null   float64
#  5   Volume        1433 non-null   int64
#  6   Price_Change  1433 non-null   float64
#  7   Target        1433 non-null   int32
#  8   MA_5          1433 non-null   float64
#  9   MA_10         1433 non-null   float64
#  10  Volatility    1433 non-null   float64
#  11  Prev_Close    1433 non-null   float64
# dtypes: float64(10), int32(1), int64(1)
# memory usage: 139.9 KB

# %%
dt_classifier = DecisionTreeClassifier(random_state=42, max_depth=5)
dt_classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
y_pred = dt_classifier.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"\nAccuracy on the test set: {accuracy:.4f}")
# Out:
# Accuracy on the test set: 0.4989

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.97      0.66       236
#            1       0.50      0.03      0.06       237
#
#     accuracy                           0.50       473
#    macro avg       0.50      0.50      0.36       473
# weighted avg       0.50      0.50      0.36       473

# %%
import seaborn as sns
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
plt.figure(figsize=(20, 10))
plot_tree(dt_classifier, feature_names=X.columns, class_names=dt_classifier.classes_.astype(str).tolist(), filled=True, fontsize=10)
plt.title("Decision Tree Visualization")
plt.show()

# %%
feature_importance = dt_classifier.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importance})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# %%
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
plt.title('Decision Tree Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for feature in X.columns:
    plt.figure(figsize=(8, 5))
    sns.histplot(X[feature], kde=True)
    plt.title(f'Distribution of {feature}')
    plt.show()

    plt.figure(figsize=(8, 5))
    sns.boxplot(x=X[feature])
    plt.title(f'Box Plot of {feature}')
    plt.show()

# %%
# Create the target variable (price direction)
df['Price_Change'] = df['Close'].diff()
df['Target'] = np.where(df['Price_Change'] > 0, 1, 0)
df = df.dropna()
df['Price_Change'] = df['Close'].diff()
df['Target'] = np.where(df['Price_Change'] > 0, 1, 0)
df = df.dropna()

df = df.dropna()
feature_columns = [col for col in df.columns if col not in ['Target', 'Date', 'Price_Change']]

# %%
sns.pairplot(df[feature_columns + ['Target']], hue='Target')
plt.suptitle('Pair Plot of Features', y=1.02)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(df['Date'], df['Close'], label="Closing Price", color='red')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Uber Stock Price Trend')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate error metrics
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error: {mae}")

# Plot actual vs predicted prices
plt.figure(figsize=(10,5))
plt.scatter(X_test['Date_ordinal'], y_test, label="Actual Price", color='blue')
plt.scatter(X_test['Date_ordinal'], y_pred, label="Predicted Price", color='red')
plt.xlabel("Date")
plt.ylabel("Stock Closing Price")
plt.title("Uber Stock Price Prediction - Decision Tree")
plt.legend()
plt.show()
# Out:
# Mean Absolute Error: 0.7551830497351678

# %%
# Get feature importance scores
importance = model.feature_importances_

# Display feature importance
feature_names = X.columns
for feature, score in zip(feature_names, importance):
    print(f"{feature}: {score:.4f}")
# Out:
# Date_ordinal: 0.0000
# Open: 0.0000
# High: 0.8511
# Low: 0.1489
# Volume: 0.0000

# %%
# Plot the Decision Tree for Uber stock prediction
fig = plt.figure(figsize=(25, 20))
_ = plot_tree(uber_clf, # Use the model trained on Uber data
              feature_names=features, # Use the features from Uber data
              class_names={0: 'Down', 1: 'Up'}, # Use the correct class names
              filled=True,
              fontsize=12)
plt.show()
